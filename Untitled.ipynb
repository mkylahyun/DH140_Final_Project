# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotify_key
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=spotify_key.CLIENT_ID,
                                                           client_secret=spotify_key.CLIENT_SECRET))

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
artist_uri = []
artist_info = []
artist_pop = []
artist_genres = []



for track in sp.playlist_tracks(playlist_URI)['items']:
  #Track id
  track_id.append(track['track']['id'])
    
  #Track name
  track_name.append(track["track"]["name"])
    
  #Main Artist
  artist_uri = track["track"]["artists"][0]["uri"]
  artist_info = sp.artist(artist_uri)
    
  #Name, popularity, genre
  artist_name.append(track["track"]["artists"][0]["name"])
  artist_pop.append(artist_info["popularity"])
  artist_genres.append(artist_info["genres"])

  #Popularity of the track
  popularity.append(track["track"]["popularity"])

# %%
audio = sp.audio_features(track_id)

# %%
sp.audio_features(track_id)
# Out:
# [{'danceability': 0.72,
#   'energy': 0.63,
#   'key': 4,
#   'loudness': -3.547,
#   'mode': 0,
#   'speechiness': 0.277,
#   'acousticness': 0.673,
#   'instrumentalness': 0,
#   'liveness': 0.0936,
#   'valence': 0.607,
#   'tempo': 179.974,
#   'type': 'audio_features',
#   'id': '0DWdj2oZMBFSzRsi2Cvfzf',
#   'uri': 'spotify:track:0DWdj2oZMBFSzRsi2Cvfzf',
#   'track_href': 'https://api.spotify.com/v1/tracks/0DWdj2oZMBFSzRsi2Cvfzf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0DWdj2oZMBFSzRsi2Cvfzf',
#   'duration_ms': 199440,
#   'time_signature': 4},
#  {'danceability': 0.531,
#   'energy': 0.525,
#   'key': 1,
#   'loudness': -6.5,
#   'mode': 0,
#   'speechiness': 0.0671,
#   'acousticness': 0.232,
#   'instrumentalness': 0,
#   'liveness': 0.441,
#   'valence': 0.502,
#   'tempo': 66.9,
#   'type': 'audio_features',
#   'id': '7oDd86yk8itslrA9HRP2ki',
#   'uri': 'spotify:track:7oDd86yk8itslrA9HRP2ki',
#   'track_href': 'https://api.spotify.com/v1/tracks/7oDd86yk8itslrA9HRP2ki',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7oDd86yk8itslrA9HRP2ki',
#   'duration_ms': 232857,
#   'time_signature': 4},
#  {'danceability': 0.707,
#   'energy': 0.681,
#   'key': 0,
#   'loudness': -4.325,
#   'mode': 1,
#   'speechiness': 0.0668,
#   'acousticness': 0.0632,
#   'instrumentalness': 5.15e-06,
#   'liveness': 0.0322,
#   'valence': 0.646,
#   'tempo': 117.999,
#   'type': 'audio_features',
#   'id': '0yLdNVWF3Srea0uzk55zFn',
#   'uri': 'spotify:track:0yLdNVWF3Srea0uzk55zFn',
#   'track_href': 'https://api.spotify.com/v1/tracks/0yLdNVWF3Srea0uzk55zFn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0yLdNVWF3Srea0uzk55zFn',
#   'duration_ms': 200455,
#   'time_signature': 4},
#  {'danceability': 0.644,
#   'energy': 0.735,
#   'key': 8,
#   'loudness': -5.747,
#   'mode': 1,
#   'speechiness': 0.0391,
#   'acousticness': 0.0521,
#   'instrumentalness': 0.144,
#   'liveness': 0.161,
#   'valence': 0.418,
#   'tempo': 88.98,
#   'type': 'audio_features',
#   'id': '1Qrg8KqiBpW07V7PNxwwwL',
#   'uri': 'spotify:track:1Qrg8KqiBpW07V7PNxwwwL',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Qrg8KqiBpW07V7PNxwwwL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Qrg8KqiBpW07V7PNxwwwL',
#   'duration_ms': 153947,
#   'time_signature': 4},
#  {'danceability': 0.696,
#   'energy': 0.809,
#   'key': 5,
#   'loudness': -8.254,
#   'mode': 1,
#   'speechiness': 0.05,
#   'acousticness': 0.252,
#   'instrumentalness': 0.000128,
#   'liveness': 0.248,
#   'valence': 0.857,
#   'tempo': 132.962,
#   'type': 'audio_features',
#   'id': '6AQbmUe0Qwf5PZnt4HmTXv',
#   'uri': 'spotify:track:6AQbmUe0Qwf5PZnt4HmTXv',
#   'track_href': 'https://api.spotify.com/v1/tracks/6AQbmUe0Qwf5PZnt4HmTXv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6AQbmUe0Qwf5PZnt4HmTXv',
#   'duration_ms': 131013,
#   'time_signature': 4},
#  {'danceability': 0.778,
#   'energy': 0.632,
#   'key': 2,
#   'loudness': -5.6,
#   'mode': 0,
#   'speechiness': 0.0493,
#   'acousticness': 0.274,
#   'instrumentalness': 0,
#   'liveness': 0.0915,
#   'valence': 0.498,
#   'tempo': 122.104,
#   'type': 'audio_features',
#   'id': '4nrPB8O7Y7wsOCJdgXkthe',
#   'uri': 'spotify:track:4nrPB8O7Y7wsOCJdgXkthe',
#   'track_href': 'https://api.spotify.com/v1/tracks/4nrPB8O7Y7wsOCJdgXkthe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4nrPB8O7Y7wsOCJdgXkthe',
#   'duration_ms': 218289,
#   'time_signature': 4},
#  {'danceability': 0.52,
#   'energy': 0.731,
#   'key': 6,
#   'loudness': -5.338,
#   'mode': 0,
#   'speechiness': 0.0557,
#   'acousticness': 0.342,
#   'instrumentalness': 0.00101,
#   'liveness': 0.311,
#   'valence': 0.662,
#   'tempo': 173.93,
#   'type': 'audio_features',
#   'id': '4Dvkj6JhhA12EX05fT7y2e',
#   'uri': 'spotify:track:4Dvkj6JhhA12EX05fT7y2e',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Dvkj6JhhA12EX05fT7y2e',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Dvkj6JhhA12EX05fT7y2e',
#   'duration_ms': 167303,
#   'time_signature': 4},
#  {'danceability': 0.715,
#   'energy': 0.62,
#   'key': 1,
#   'loudness': -6.005,
#   'mode': 0,
#   'speechiness': 0.0484,
#   'acousticness': 0.417,
#   'instrumentalness': 0,
#   'liveness': 0.0822,
#   'valence': 0.172,
#   'tempo': 97.95,
#   'type': 'audio_features',
#   'id': '2dHHgzDwk4BJdRwy9uXhTO',
#   'uri': 'spotify:track:2dHHgzDwk4BJdRwy9uXhTO',
#   'track_href': 'https://api.spotify.com/v1/tracks/2dHHgzDwk4BJdRwy9uXhTO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2dHHgzDwk4BJdRwy9uXhTO',
#   'duration_ms': 221520,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.729,
#   'key': 6,
#   'loudness': -3.549,
#   'mode': 0,
#   'speechiness': 0.0691,
#   'acousticness': 0.0492,
#   'instrumentalness': 0.000272,
#   'liveness': 0.1,
#   'valence': 0.58,
#   'tempo': 167.968,
#   'type': 'audio_features',
#   'id': '4FAKtPVycI4DxoOHC01YqD',
#   'uri': 'spotify:track:4FAKtPVycI4DxoOHC01YqD',
#   'track_href': 'https://api.spotify.com/v1/tracks/4FAKtPVycI4DxoOHC01YqD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4FAKtPVycI4DxoOHC01YqD',
#   'duration_ms': 216148,
#   'time_signature': 4},
#  {'danceability': 0.801,
#   'energy': 0.806,
#   'key': 11,
#   'loudness': -5.206,
#   'mode': 1,
#   'speechiness': 0.0381,
#   'acousticness': 0.382,
#   'instrumentalness': 0.000669,
#   'liveness': 0.114,
#   'valence': 0.802,
#   'tempo': 106.999,
#   'type': 'audio_features',
#   'id': '0WtM2NBVQNNJLh6scP13H8',
#   'uri': 'spotify:track:0WtM2NBVQNNJLh6scP13H8',
#   'track_href': 'https://api.spotify.com/v1/tracks/0WtM2NBVQNNJLh6scP13H8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0WtM2NBVQNNJLh6scP13H8',
#   'duration_ms': 239318,
#   'time_signature': 4},
#  {'danceability': 0.712,
#   'energy': 0.463,
#   'key': 2,
#   'loudness': -7.399,
#   'mode': 1,
#   'speechiness': 0.0797,
#   'acousticness': 0.011,
#   'instrumentalness': 2.96e-06,
#   'liveness': 0.301,
#   'valence': 0.206,
#   'tempo': 131.199,
#   'type': 'audio_features',
#   'id': '0NZPBYD5qbEWRs3PrGiRkT',
#   'uri': 'spotify:track:0NZPBYD5qbEWRs3PrGiRkT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0NZPBYD5qbEWRs3PrGiRkT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0NZPBYD5qbEWRs3PrGiRkT',
#   'duration_ms': 156943,
#   'time_signature': 4},
#  {'danceability': 0.637,
#   'energy': 0.768,
#   'key': 0,
#   'loudness': -6.468,
#   'mode': 1,
#   'speechiness': 0.056,
#   'acousticness': 0.458,
#   'instrumentalness': 0.00192,
#   'liveness': 0.378,
#   'valence': 0.297,
#   'tempo': 94.982,
#   'type': 'audio_features',
#   'id': '38UYeBLfvpnDSG9GznZdnL',
#   'uri': 'spotify:track:38UYeBLfvpnDSG9GznZdnL',
#   'track_href': 'https://api.spotify.com/v1/tracks/38UYeBLfvpnDSG9GznZdnL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/38UYeBLfvpnDSG9GznZdnL',
#   'duration_ms': 193464,
#   'time_signature': 4},
#  {'danceability': 0.835,
#   'energy': 0.679,
#   'key': 7,
#   'loudness': -5.329,
#   'mode': 0,
#   'speechiness': 0.0364,
#   'acousticness': 0.583,
#   'instrumentalness': 1.98e-06,
#   'liveness': 0.218,
#   'valence': 0.85,
#   'tempo': 124.98,
#   'type': 'audio_features',
#   'id': '5ww2BF9slyYgNOk37BlC4u',
#   'uri': 'spotify:track:5ww2BF9slyYgNOk37BlC4u',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ww2BF9slyYgNOk37BlC4u',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ww2BF9slyYgNOk37BlC4u',
#   'duration_ms': 162638,
#   'time_signature': 4},
#  {'danceability': 0.492,
#   'energy': 0.675,
#   'key': 6,
#   'loudness': -5.456,
#   'mode': 1,
#   'speechiness': 0.0389,
#   'acousticness': 0.467,
#   'instrumentalness': 0,
#   'liveness': 0.142,
#   'valence': 0.478,
#   'tempo': 203.759,
#   'type': 'audio_features',
#   'id': '7K3BhSpAxZBznislvUMVtn',
#   'uri': 'spotify:track:7K3BhSpAxZBznislvUMVtn',
#   'track_href': 'https://api.spotify.com/v1/tracks/7K3BhSpAxZBznislvUMVtn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7K3BhSpAxZBznislvUMVtn',
#   'duration_ms': 163855,
#   'time_signature': 4},
#  {'danceability': 0.561,
#   'energy': 0.965,
#   'key': 7,
#   'loudness': -3.673,
#   'mode': 0,
#   'speechiness': 0.0343,
#   'acousticness': 0.00383,
#   'instrumentalness': 7.07e-06,
#   'liveness': 0.371,
#   'valence': 0.304,
#   'tempo': 128.04,
#   'type': 'audio_features',
#   'id': '4uUG5RXrOk84mYEfFvj3cK',
#   'uri': 'spotify:track:4uUG5RXrOk84mYEfFvj3cK',
#   'track_href': 'https://api.spotify.com/v1/tracks/4uUG5RXrOk84mYEfFvj3cK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4uUG5RXrOk84mYEfFvj3cK',
#   'duration_ms': 175238,
#   'time_signature': 4},
#  {'danceability': 0.586,
#   'energy': 0.525,
#   'key': 1,
#   'loudness': -7.163,
#   'mode': 0,
#   'speechiness': 0.0615,
#   'acousticness': 0.111,
#   'instrumentalness': 0,
#   'liveness': 0.134,
#   'valence': 0.508,
#   'tempo': 133.629,
#   'type': 'audio_features',
#   'id': '2LBqCSwhJGcFQeTHMVGwy3',
#   'uri': 'spotify:track:2LBqCSwhJGcFQeTHMVGwy3',
#   'track_href': 'https://api.spotify.com/v1/tracks/2LBqCSwhJGcFQeTHMVGwy3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2LBqCSwhJGcFQeTHMVGwy3',
#   'duration_ms': 260253,
#   'time_signature': 4},
#  {'danceability': 0.901,
#   'energy': 0.589,
#   'key': 1,
#   'loudness': -6.713,
#   'mode': 0,
#   'speechiness': 0.289,
#   'acousticness': 0.00302,
#   'instrumentalness': 0.000237,
#   'liveness': 0.0992,
#   'valence': 0.399,
#   'tempo': 98.002,
#   'type': 'audio_features',
#   'id': '1zsPaEkglFvxjAhrM8yhpr',
#   'uri': 'spotify:track:1zsPaEkglFvxjAhrM8yhpr',
#   'track_href': 'https://api.spotify.com/v1/tracks/1zsPaEkglFvxjAhrM8yhpr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zsPaEkglFvxjAhrM8yhpr',
#   'duration_ms': 196600,
#   'time_signature': 4},
#  {'danceability': 0.538,
#   'energy': 0.742,
#   'key': 2,
#   'loudness': -5.355,
#   'mode': 1,
#   'speechiness': 0.114,
#   'acousticness': 0.138,
#   'instrumentalness': 4.67e-05,
#   'liveness': 0.0934,
#   'valence': 0.25,
#   'tempo': 96.107,
#   'type': 'audio_features',
#   'id': '5mHdCZtVyb4DcJw8799hZp',
#   'uri': 'spotify:track:5mHdCZtVyb4DcJw8799hZp',
#   'track_href': 'https://api.spotify.com/v1/tracks/5mHdCZtVyb4DcJw8799hZp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mHdCZtVyb4DcJw8799hZp',
#   'duration_ms': 272373,
#   'time_signature': 4},
#  {'danceability': 0.574,
#   'energy': 0.469,
#   'key': 4,
#   'loudness': -8.209,
#   'mode': 1,
#   'speechiness': 0.0254,
#   'acousticness': 0.534,
#   'instrumentalness': 9.21e-05,
#   'liveness': 0.128,
#   'valence': 0.288,
#   'tempo': 132.023,
#   'type': 'audio_features',
#   'id': '78Sw5GDo6AlGwTwanjXbGh',
#   'uri': 'spotify:track:78Sw5GDo6AlGwTwanjXbGh',
#   'track_href': 'https://api.spotify.com/v1/tracks/78Sw5GDo6AlGwTwanjXbGh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78Sw5GDo6AlGwTwanjXbGh',
#   'duration_ms': 242485,
#   'time_signature': 4},
#  {'danceability': 0.637,
#   'energy': 0.643,
#   'key': 4,
#   'loudness': -6.571,
#   'mode': 1,
#   'speechiness': 0.0519,
#   'acousticness': 0.13,
#   'instrumentalness': 1.8e-06,
#   'liveness': 0.142,
#   'valence': 0.533,
#   'tempo': 97.008,
#   'type': 'audio_features',
#   'id': '0V3wPSX9ygBnCm8psDIegu',
#   'uri': 'spotify:track:0V3wPSX9ygBnCm8psDIegu',
#   'track_href': 'https://api.spotify.com/v1/tracks/0V3wPSX9ygBnCm8psDIegu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0V3wPSX9ygBnCm8psDIegu',
#   'duration_ms': 200690,
#   'time_signature': 4},
#  {'danceability': 0.804,
#   'energy': 0.771,
#   'key': 9,
#   'loudness': -4.067,
#   'mode': 0,
#   'speechiness': 0.0433,
#   'acousticness': 0.357,
#   'instrumentalness': 3.07e-06,
#   'liveness': 0.108,
#   'valence': 0.739,
#   'tempo': 126.956,
#   'type': 'audio_features',
#   'id': '65FftemJ1DbbZ45DUfHJXE',
#   'uri': 'spotify:track:65FftemJ1DbbZ45DUfHJXE',
#   'track_href': 'https://api.spotify.com/v1/tracks/65FftemJ1DbbZ45DUfHJXE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/65FftemJ1DbbZ45DUfHJXE',
#   'duration_ms': 212253,
#   'time_signature': 4},
#  {'danceability': 0.551,
#   'energy': 0.55,
#   'key': 10,
#   'loudness': -5.339,
#   'mode': 1,
#   'speechiness': 0.0286,
#   'acousticness': 0.777,
#   'instrumentalness': 0,
#   'liveness': 0.202,
#   'valence': 0.342,
#   'tempo': 101.19,
#   'type': 'audio_features',
#   'id': '1Y3LN4zO1Edc2EluIoSPJN',
#   'uri': 'spotify:track:1Y3LN4zO1Edc2EluIoSPJN',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Y3LN4zO1Edc2EluIoSPJN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Y3LN4zO1Edc2EluIoSPJN',
#   'duration_ms': 176440,
#   'time_signature': 3},
#  {'danceability': 0.679,
#   'energy': 0.587,
#   'key': 7,
#   'loudness': -7.015,
#   'mode': 1,
#   'speechiness': 0.276,
#   'acousticness': 0.141,
#   'instrumentalness': 6.35e-06,
#   'liveness': 0.137,
#   'valence': 0.486,
#   'tempo': 186.003,
#   'type': 'audio_features',
#   'id': '7MXVkk9YMctZqd1Srtv4MB',
#   'uri': 'spotify:track:7MXVkk9YMctZqd1Srtv4MB',
#   'track_href': 'https://api.spotify.com/v1/tracks/7MXVkk9YMctZqd1Srtv4MB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MXVkk9YMctZqd1Srtv4MB',
#   'duration_ms': 230453,
#   'time_signature': 4},
#  {'danceability': 0.794,
#   'energy': 0.807,
#   'key': 1,
#   'loudness': -3.447,
#   'mode': 0,
#   'speechiness': 0.326,
#   'acousticness': 0.334,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.575,
#   'tempo': 178.003,
#   'type': 'audio_features',
#   'id': '4NoOME4Dhf4xgxbHDT7VGe',
#   'uri': 'spotify:track:4NoOME4Dhf4xgxbHDT7VGe',
#   'track_href': 'https://api.spotify.com/v1/tracks/4NoOME4Dhf4xgxbHDT7VGe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NoOME4Dhf4xgxbHDT7VGe',
#   'duration_ms': 200120,
#   'time_signature': 4},
#  {'danceability': 0.681,
#   'energy': 0.821,
#   'key': 11,
#   'loudness': -5.12,
#   'mode': 0,
#   'speechiness': 0.131,
#   'acousticness': 0.532,
#   'instrumentalness': 0.00111,
#   'liveness': 0.0921,
#   'valence': 0.813,
#   'tempo': 94.074,
#   'type': 'audio_features',
#   'id': '5wxYxygyHpbgv0EXZuqb9V',
#   'uri': 'spotify:track:5wxYxygyHpbgv0EXZuqb9V',
#   'track_href': 'https://api.spotify.com/v1/tracks/5wxYxygyHpbgv0EXZuqb9V',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5wxYxygyHpbgv0EXZuqb9V',
#   'duration_ms': 214701,
#   'time_signature': 4},
#  {'danceability': 0.442,
#   'energy': 0.538,
#   'key': 4,
#   'loudness': -8.55,
#   'mode': 0,
#   'speechiness': 0.0451,
#   'acousticness': 0.717,
#   'instrumentalness': 2.95e-05,
#   'liveness': 0.09,
#   'valence': 0.139,
#   'tempo': 122.758,
#   'type': 'audio_features',
#   'id': '7jtQIBanIiJOMS6RyCx6jZ',
#   'uri': 'spotify:track:7jtQIBanIiJOMS6RyCx6jZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/7jtQIBanIiJOMS6RyCx6jZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7jtQIBanIiJOMS6RyCx6jZ',
#   'duration_ms': 244360,
#   'time_signature': 4},
#  {'danceability': 0.515,
#   'energy': 0.593,
#   'key': 4,
#   'loudness': -4.801,
#   'mode': 1,
#   'speechiness': 0.0322,
#   'acousticness': 0.653,
#   'instrumentalness': 0.162,
#   'liveness': 0.25,
#   'valence': 0.153,
#   'tempo': 94.467,
#   'type': 'audio_features',
#   'id': '5odlY52u43F5BjByhxg7wg',
#   'uri': 'spotify:track:5odlY52u43F5BjByhxg7wg',
#   'track_href': 'https://api.spotify.com/v1/tracks/5odlY52u43F5BjByhxg7wg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5odlY52u43F5BjByhxg7wg',
#   'duration_ms': 209260,
#   'time_signature': 3},
#  {'danceability': 0.887,
#   'energy': 0.234,
#   'key': 9,
#   'loudness': -14.52,
#   'mode': 1,
#   'speechiness': 0.178,
#   'acousticness': 0.111,
#   'instrumentalness': 0.67,
#   'liveness': 0.13,
#   'valence': 0.197,
#   'tempo': 140.02,
#   'type': 'audio_features',
#   'id': '2mnXxnrX5vCGolNkaFvVeM',
#   'uri': 'spotify:track:2mnXxnrX5vCGolNkaFvVeM',
#   'track_href': 'https://api.spotify.com/v1/tracks/2mnXxnrX5vCGolNkaFvVeM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mnXxnrX5vCGolNkaFvVeM',
#   'duration_ms': 196800,
#   'time_signature': 4},
#  {'danceability': 0.621,
#   'energy': 0.782,
#   'key': 2,
#   'loudness': -5.548,
#   'mode': 1,
#   'speechiness': 0.044,
#   'acousticness': 0.0125,
#   'instrumentalness': 0.033,
#   'liveness': 0.23,
#   'valence': 0.55,
#   'tempo': 128.033,
#   'type': 'audio_features',
#   'id': '2tTmW7RDtMQtBk7m2rYeSw',
#   'uri': 'spotify:track:2tTmW7RDtMQtBk7m2rYeSw',
#   'track_href': 'https://api.spotify.com/v1/tracks/2tTmW7RDtMQtBk7m2rYeSw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tTmW7RDtMQtBk7m2rYeSw',
#   'duration_ms': 198938,
#   'time_signature': 4},
#  {'danceability': 0.772,
#   'energy': 0.73,
#   'key': 11,
#   'loudness': -6.657,
#   'mode': 0,
#   'speechiness': 0.0972,
#   'acousticness': 0.152,
#   'instrumentalness': 0.000107,
#   'liveness': 0.274,
#   'valence': 0.786,
#   'tempo': 136.175,
#   'type': 'audio_features',
#   'id': '1lRtH4FszTrwwlK5gTSbXO',
#   'uri': 'spotify:track:1lRtH4FszTrwwlK5gTSbXO',
#   'track_href': 'https://api.spotify.com/v1/tracks/1lRtH4FszTrwwlK5gTSbXO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1lRtH4FszTrwwlK5gTSbXO',
#   'duration_ms': 174943,
#   'time_signature': 3},
#  {'danceability': 0.954,
#   'energy': 0.516,
#   'key': 6,
#   'loudness': -5.817,
#   'mode': 1,
#   'speechiness': 0.16,
#   'acousticness': 0.03,
#   'instrumentalness': 7.54e-06,
#   'liveness': 0.0504,
#   'valence': 0.624,
#   'tempo': 105.001,
#   'type': 'audio_features',
#   'id': '6UN73IYd0hZxLi8wFPMQij',
#   'uri': 'spotify:track:6UN73IYd0hZxLi8wFPMQij',
#   'track_href': 'https://api.spotify.com/v1/tracks/6UN73IYd0hZxLi8wFPMQij',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6UN73IYd0hZxLi8wFPMQij',
#   'duration_ms': 139560,
#   'time_signature': 4},
#  {'danceability': 0.697,
#   'energy': 0.802,
#   'key': 0,
#   'loudness': -6.412,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.0988,
#   'instrumentalness': 3.55e-05,
#   'liveness': 0.0614,
#   'valence': 0.822,
#   'tempo': 139.951,
#   'type': 'audio_features',
#   'id': '4fYte8ZvTK14NEhAOZocBi',
#   'uri': 'spotify:track:4fYte8ZvTK14NEhAOZocBi',
#   'track_href': 'https://api.spotify.com/v1/tracks/4fYte8ZvTK14NEhAOZocBi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4fYte8ZvTK14NEhAOZocBi',
#   'duration_ms': 148120,
#   'time_signature': 4},
#  {'danceability': 0.464,
#   'energy': 0.417,
#   'key': 0,
#   'loudness': -9.345,
#   'mode': 0,
#   'speechiness': 0.0256,
#   'acousticness': 0.136,
#   'instrumentalness': 0.022,
#   'liveness': 0.0974,
#   'valence': 0.479,
#   'tempo': 67.528,
#   'type': 'audio_features',
#   'id': '5XeFesFbtLpXzIVDNQP22n',
#   'uri': 'spotify:track:5XeFesFbtLpXzIVDNQP22n',
#   'track_href': 'https://api.spotify.com/v1/tracks/5XeFesFbtLpXzIVDNQP22n',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XeFesFbtLpXzIVDNQP22n',
#   'duration_ms': 183956,
#   'time_signature': 4},
#  {'danceability': 0.784,
#   'energy': 0.826,
#   'key': 7,
#   'loudness': -6.34,
#   'mode': 0,
#   'speechiness': 0.0538,
#   'acousticness': 0.0965,
#   'instrumentalness': 7.09e-05,
#   'liveness': 0.123,
#   'valence': 0.893,
#   'tempo': 138.078,
#   'type': 'audio_features',
#   'id': '2mpoNBkngUEwnaKoBhZ0vl',
#   'uri': 'spotify:track:2mpoNBkngUEwnaKoBhZ0vl',
#   'track_href': 'https://api.spotify.com/v1/tracks/2mpoNBkngUEwnaKoBhZ0vl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mpoNBkngUEwnaKoBhZ0vl',
#   'duration_ms': 184066,
#   'time_signature': 3},
#  {'danceability': 0.865,
#   'energy': 0.573,
#   'key': 5,
#   'loudness': -5.501,
#   'mode': 1,
#   'speechiness': 0.0678,
#   'acousticness': 0.0863,
#   'instrumentalness': 0,
#   'liveness': 0.305,
#   'valence': 0.563,
#   'tempo': 94.999,
#   'type': 'audio_features',
#   'id': '2CeKVsFFXG4QzA415QygGb',
#   'uri': 'spotify:track:2CeKVsFFXG4QzA415QygGb',
#   'track_href': 'https://api.spotify.com/v1/tracks/2CeKVsFFXG4QzA415QygGb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2CeKVsFFXG4QzA415QygGb',
#   'duration_ms': 155960,
#   'time_signature': 4},
#  {'danceability': 0.684,
#   'energy': 0.607,
#   'key': 11,
#   'loudness': -8.127,
#   'mode': 0,
#   'speechiness': 0.1,
#   'acousticness': 0.0267,
#   'instrumentalness': 0.000307,
#   'liveness': 0.191,
#   'valence': 0.498,
#   'tempo': 81.001,
#   'type': 'audio_features',
#   'id': '0JXXNGljqupsJaZsgSbMZV',
#   'uri': 'spotify:track:0JXXNGljqupsJaZsgSbMZV',
#   'track_href': 'https://api.spotify.com/v1/tracks/0JXXNGljqupsJaZsgSbMZV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0JXXNGljqupsJaZsgSbMZV',
#   'duration_ms': 195373,
#   'time_signature': 4},
#  {'danceability': 0.559,
#   'energy': 0.551,
#   'key': 5,
#   'loudness': -7.231,
#   'mode': 1,
#   'speechiness': 0.132,
#   'acousticness': 0.141,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.392,
#   'tempo': 143.008,
#   'type': 'audio_features',
#   'id': '4iZ4pt7kvcaH6Yo8UoZ4s2',
#   'uri': 'spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2',
#   'track_href': 'https://api.spotify.com/v1/tracks/4iZ4pt7kvcaH6Yo8UoZ4s2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4iZ4pt7kvcaH6Yo8UoZ4s2',
#   'duration_ms': 201800,
#   'time_signature': 4},
#  {'danceability': 0.516,
#   'energy': 0.322,
#   'key': 9,
#   'loudness': -11.762,
#   'mode': 1,
#   'speechiness': 0.0292,
#   'acousticness': 0.473,
#   'instrumentalness': 0.00194,
#   'liveness': 0.215,
#   'valence': 0.261,
#   'tempo': 148.005,
#   'type': 'audio_features',
#   'id': '2L9N0zZnd37dwF0clgxMGI',
#   'uri': 'spotify:track:2L9N0zZnd37dwF0clgxMGI',
#   'track_href': 'https://api.spotify.com/v1/tracks/2L9N0zZnd37dwF0clgxMGI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2L9N0zZnd37dwF0clgxMGI',
#   'duration_ms': 182888,
#   'time_signature': 3},
#  {'danceability': 0.772,
#   'energy': 0.75,
#   'key': 5,
#   'loudness': -3.67,
#   'mode': 0,
#   'speechiness': 0.0455,
#   'acousticness': 0.0201,
#   'instrumentalness': 0,
#   'liveness': 0.074,
#   'valence': 0.587,
#   'tempo': 114.061,
#   'type': 'audio_features',
#   'id': '54ipXppHLA8U4yqpOFTUhr',
#   'uri': 'spotify:track:54ipXppHLA8U4yqpOFTUhr',
#   'track_href': 'https://api.spotify.com/v1/tracks/54ipXppHLA8U4yqpOFTUhr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/54ipXppHLA8U4yqpOFTUhr',
#   'duration_ms': 165265,
#   'time_signature': 4},
#  {'danceability': 0.486,
#   'energy': 0.545,
#   'key': 11,
#   'loudness': -7.924,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.0652,
#   'instrumentalness': 0.00474,
#   'liveness': 0.0642,
#   'valence': 0.0385,
#   'tempo': 150.187,
#   'type': 'audio_features',
#   'id': '4FyesJzVpA39hbYvcseO2d',
#   'uri': 'spotify:track:4FyesJzVpA39hbYvcseO2d',
#   'track_href': 'https://api.spotify.com/v1/tracks/4FyesJzVpA39hbYvcseO2d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4FyesJzVpA39hbYvcseO2d',
#   'duration_ms': 123891,
#   'time_signature': 4},
#  {'danceability': 0.529,
#   'energy': 0.602,
#   'key': 7,
#   'loudness': -4.629,
#   'mode': 1,
#   'speechiness': 0.0458,
#   'acousticness': 0.299,
#   'instrumentalness': 0,
#   'liveness': 0.0716,
#   'valence': 0.756,
#   'tempo': 157.643,
#   'type': 'audio_features',
#   'id': '0IKeDy5bT9G0bA7ZixRT4A',
#   'uri': 'spotify:track:0IKeDy5bT9G0bA7ZixRT4A',
#   'track_href': 'https://api.spotify.com/v1/tracks/0IKeDy5bT9G0bA7ZixRT4A',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0IKeDy5bT9G0bA7ZixRT4A',
#   'duration_ms': 271862,
#   'time_signature': 4},
#  {'danceability': 0.637,
#   'energy': 0.678,
#   'key': 0,
#   'loudness': -3.798,
#   'mode': 1,
#   'speechiness': 0.266,
#   'acousticness': 0.209,
#   'instrumentalness': 0,
#   'liveness': 0.156,
#   'valence': 0.254,
#   'tempo': 84.039,
#   'type': 'audio_features',
#   'id': '561jH07mF1jHuk7KlaeF0s',
#   'uri': 'spotify:track:561jH07mF1jHuk7KlaeF0s',
#   'track_href': 'https://api.spotify.com/v1/tracks/561jH07mF1jHuk7KlaeF0s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/561jH07mF1jHuk7KlaeF0s',
#   'duration_ms': 250760,
#   'time_signature': 4},
#  {'danceability': 0.814,
#   'energy': 0.641,
#   'key': 6,
#   'loudness': -5.957,
#   'mode': 0,
#   'speechiness': 0.111,
#   'acousticness': 0.027,
#   'instrumentalness': 0,
#   'liveness': 0.0993,
#   'valence': 0.183,
#   'tempo': 133.854,
#   'type': 'audio_features',
#   'id': '3r8RuvgbX9s7ammBn07D3W',
#   'uri': 'spotify:track:3r8RuvgbX9s7ammBn07D3W',
#   'track_href': 'https://api.spotify.com/v1/tracks/3r8RuvgbX9s7ammBn07D3W',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3r8RuvgbX9s7ammBn07D3W',
#   'duration_ms': 185507,
#   'time_signature': 4},
#  {'danceability': 0.911,
#   'energy': 0.712,
#   'key': 1,
#   'loudness': -5.105,
#   'mode': 0,
#   'speechiness': 0.0817,
#   'acousticness': 0.0901,
#   'instrumentalness': 2.68e-05,
#   'liveness': 0.0933,
#   'valence': 0.425,
#   'tempo': 92.005,
#   'type': 'audio_features',
#   'id': '6Sq7ltF9Qa7SNFBsV5Cogx',
#   'uri': 'spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Sq7ltF9Qa7SNFBsV5Cogx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Sq7ltF9Qa7SNFBsV5Cogx',
#   'duration_ms': 178567,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.69,
#   'key': 9,
#   'loudness': -5.529,
#   'mode': 0,
#   'speechiness': 0.0427,
#   'acousticness': 0.0635,
#   'instrumentalness': 1.18e-06,
#   'liveness': 0.105,
#   'valence': 0.31,
#   'tempo': 116.992,
#   'type': 'audio_features',
#   'id': '5IgjP7X4th6nMNDh4akUHb',
#   'uri': 'spotify:track:5IgjP7X4th6nMNDh4akUHb',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IgjP7X4th6nMNDh4akUHb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IgjP7X4th6nMNDh4akUHb',
#   'duration_ms': 184613,
#   'time_signature': 4},
#  {'danceability': 0.561,
#   'energy': 0.52,
#   'key': 11,
#   'loudness': -9.342,
#   'mode': 0,
#   'speechiness': 0.244,
#   'acousticness': 0.0503,
#   'instrumentalness': 1.86e-06,
#   'liveness': 0.355,
#   'valence': 0.424,
#   'tempo': 153.15,
#   'type': 'audio_features',
#   'id': '1bDbXMyjaUIooNwFE9wn0N',
#   'uri': 'spotify:track:1bDbXMyjaUIooNwFE9wn0N',
#   'track_href': 'https://api.spotify.com/v1/tracks/1bDbXMyjaUIooNwFE9wn0N',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1bDbXMyjaUIooNwFE9wn0N',
#   'duration_ms': 239360,
#   'time_signature': 3},
#  {'danceability': 0.514,
#   'energy': 0.73,
#   'key': 1,
#   'loudness': -5.934,
#   'mode': 1,
#   'speechiness': 0.0598,
#   'acousticness': 0.00146,
#   'instrumentalness': 9.54e-05,
#   'liveness': 0.0897,
#   'valence': 0.334,
#   'tempo': 171.005,
#   'type': 'audio_features',
#   'id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b',
#   'track_href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VjIjW4GlUZAMYd2vXMi3b',
#   'duration_ms': 200040,
#   'time_signature': 4},
#  {'danceability': 0.838,
#   'energy': 0.79,
#   'key': 6,
#   'loudness': -1.602,
#   'mode': 0,
#   'speechiness': 0.108,
#   'acousticness': 0.431,
#   'instrumentalness': 3.33e-06,
#   'liveness': 0.184,
#   'valence': 0.962,
#   'tempo': 92.927,
#   'type': 'audio_features',
#   'id': '1DxEbt6OSbrkRthk6pjZue',
#   'uri': 'spotify:track:1DxEbt6OSbrkRthk6pjZue',
#   'track_href': 'https://api.spotify.com/v1/tracks/1DxEbt6OSbrkRthk6pjZue',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DxEbt6OSbrkRthk6pjZue',
#   'duration_ms': 161452,
#   'time_signature': 4},
#  {'danceability': 0.743,
#   'energy': 0.831,
#   'key': 8,
#   'loudness': -4.042,
#   'mode': 0,
#   'speechiness': 0.0584,
#   'acousticness': 0.114,
#   'instrumentalness': 6.43e-05,
#   'liveness': 0.35,
#   'valence': 0.609,
#   'tempo': 95.975,
#   'type': 'audio_features',
#   'id': '0CYTGMBYkwUxrj1MWDLrC5',
#   'uri': 'spotify:track:0CYTGMBYkwUxrj1MWDLrC5',
#   'track_href': 'https://api.spotify.com/v1/tracks/0CYTGMBYkwUxrj1MWDLrC5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0CYTGMBYkwUxrj1MWDLrC5',
#   'duration_ms': 168133,
#   'time_signature': 4},
#  {'danceability': 0.691,
#   'energy': 0.708,
#   'key': 9,
#   'loudness': -4.821,
#   'mode': 1,
#   'speechiness': 0.195,
#   'acousticness': 0.338,
#   'instrumentalness': 0,
#   'liveness': 0.311,
#   'valence': 0.602,
#   'tempo': 160.018,
#   'type': 'audio_features',
#   'id': '4uqJelb9THHmJ3OCohg4ZJ',
#   'uri': 'spotify:track:4uqJelb9THHmJ3OCohg4ZJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4uqJelb9THHmJ3OCohg4ZJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4uqJelb9THHmJ3OCohg4ZJ',
#   'duration_ms': 173698,
#   'time_signature': 4}]

# %%
list(audio)[0]['danceability']
# Out:
# 0.72

# %%
import pandas as pd

# %%
audio_df = pd.DataFrame(sp.audio_features(track_id))
audio_df = audio_df[['acousticness','danceability','energy','instrumentalness','loudness','speechiness','tempo','valence']]

# %%
track_df = pd.DataFrame({'artist_name' : artist_name,
                        'track_name' : track_name,
                        'track_id' : track_id,
                        'track popularity': popularity,
                        'artist popularity': artist_pop,
                        'artist genre': artist_genres,
                        'acousticness': list(audio_df['acousticness']),
                        'danceability': list(audio_df['danceability']),
                        'energy': list(audio_df['energy']),
                        'instrumentalness':  list(audio_df['instrumentalness']),
                        'loudness': list(audio_df['loudness']),
                        'speechiness': list(audio_df['speechiness']),
                        'tempo': list(audio_df['tempo']),
                        'valence': list(audio_df['valence'])})

# %%
track_df
# Out:
#         artist_name                                         track_name  \
# 0           KAROL G                                                TQG
# 1        The Weeknd                                Die For You - Remix
# 2       Miley Cyrus                                            Flowers
# 3               SZA                                          Kill Bill
# 4    PinkPantheress                                 Boy's a liar Pt. 2
# 5          Bizarrap              Shakira: Bzrp Music Sessions, Vol. 53
# 6      Harry Styles                                          As It Was
# 7      Metro Boomin             Creepin' (with The Weeknd & 21 Savage)
# 8            Yandel                                         Yandel 150
# 9              Rema                      Calm Down (with Selena Gomez)
# 10        Sam Smith                          Unholy (feat. Kim Petras)
# 11         Gorillaz                         Tormenta (feat. Bad Bunny)
# 12    Manuel Turizo                                         La Bachata
# 13    Morgan Wallen                                         Last Night
# 14     David Guetta                                    I'm Good (Blue)
# 15       The Weeknd                                        Die For You
# 16            Ozuna                                            Hey Mor
# 17             RAYE                                          Escapism.
# 18             d4vd                                       Here With Me
# 19     Taylor Swift                                          Anti-Hero
# 20         NewJeans                                                OMG
# 21  Stephen Sanchez  Until I Found You (with Em Beihold) - Em Beiho...
# 22       The Weeknd                                            Starboy
# 23          KAROL G                                      X SI VOLVEMOS
# 24           j-hope                       on the street (with J. Cole)
# 25        Tom Odell                                       Another Love
# 26             JVKE                                        golden hour
# 27         Arcángel                                           La Jumpa
# 28         Bizarrap              Quevedo: Bzrp Music Sessions, Vol. 52
# 29    Natanael Cano                                                AMG
# 30        Coi Leray                                            Players
# 31      OneRepublic                                    I Ain't Worried
# 32   Arctic Monkeys                                   I Wanna Be Yours
# 33       Peso Pluma                                                PRC
# 34             Feid                            Feliz Cumpleaños Ferxxo
# 35           Miguel                                         Sure Thing
# 36              SZA                                             Snooze
# 37   Lizzy McAlpine                                           ceilings
# 38  Imagine Dragons                                              Bones
# 39     Lil Uzi Vert                                    Just Wanna Rock
# 40    Fuerza Regida                                          Bebe Dame
# 41           Eminem                                        Mockingbird
# 42         NewJeans                                              Ditto
# 43        Bad Bunny                                    Me Porto Bonito
# 44      Chris Brown                                Under The Influence
# 45            Drake                                          Rich Flex
# 46       The Weeknd                                    Blinding Lights
# 47         LiL CaKe                                             MERCHO
# 48             Feid                             CHORRITO PA LAS ANIMAS
# 49         AgroPlay                                       Nosso Quadro
#
#                   track_id  track popularity  artist popularity  \
# 0   0DWdj2oZMBFSzRsi2Cvfzf                93                 94
# 1   7oDd86yk8itslrA9HRP2ki                93                 99
# 2   0yLdNVWF3Srea0uzk55zFn               100                 92
# 3   1Qrg8KqiBpW07V7PNxwwwL                93                 95
# 4   6AQbmUe0Qwf5PZnt4HmTXv                94                 86
# 5   4nrPB8O7Y7wsOCJdgXkthe                96                 89
# 6   4Dvkj6JhhA12EX05fT7y2e                89                 92
# 7   2dHHgzDwk4BJdRwy9uXhTO                94                 92
# 8   4FAKtPVycI4DxoOHC01YqD                86                 84
# 9   0WtM2NBVQNNJLh6scP13H8                92                 84
# 10  0NZPBYD5qbEWRs3PrGiRkT                84                 90
# 11  38UYeBLfvpnDSG9GznZdnL                86                 86
# 12  5ww2BF9slyYgNOk37BlC4u                93                 86
# 13  7K3BhSpAxZBznislvUMVtn                80                 94
# 14  4uUG5RXrOk84mYEfFvj3cK                93                 91
# 15  2LBqCSwhJGcFQeTHMVGwy3                88                 99
# 16  1zsPaEkglFvxjAhrM8yhpr                89                 91
# 17  5mHdCZtVyb4DcJw8799hZp                78                 84
# 18  78Sw5GDo6AlGwTwanjXbGh                92                 84
# 19  0V3wPSX9ygBnCm8psDIegu                92                 99
# 20  65FftemJ1DbbZ45DUfHJXE                91                 86
# 21  1Y3LN4zO1Edc2EluIoSPJN                90                 82
# 22  7MXVkk9YMctZqd1Srtv4MB                90                 99
# 23  4NoOME4Dhf4xgxbHDT7VGe                82                 94
# 24  5wxYxygyHpbgv0EXZuqb9V                85                 80
# 25  7jtQIBanIiJOMS6RyCx6jZ                60                 80
# 26  5odlY52u43F5BjByhxg7wg                88                 83
# 27  2mnXxnrX5vCGolNkaFvVeM                85                 87
# 28  2tTmW7RDtMQtBk7m2rYeSw                91                 89
# 29  1lRtH4FszTrwwlK5gTSbXO                89                 87
# 30  6UN73IYd0hZxLi8wFPMQij                89                 79
# 31  4fYte8ZvTK14NEhAOZocBi                46                 86
# 32  5XeFesFbtLpXzIVDNQP22n                90                 89
# 33  2mpoNBkngUEwnaKoBhZ0vl                89                 88
# 34  2CeKVsFFXG4QzA415QygGb                86                 94
# 35  0JXXNGljqupsJaZsgSbMZV                90                 85
# 36  4iZ4pt7kvcaH6Yo8UoZ4s2                89                 95
# 37  2L9N0zZnd37dwF0clgxMGI                87                 78
# 38  54ipXppHLA8U4yqpOFTUhr                84                 91
# 39  4FyesJzVpA39hbYvcseO2d                89                 90
# 40  0IKeDy5bT9G0bA7ZixRT4A                80                 88
# 41  561jH07mF1jHuk7KlaeF0s                89                 94
# 42  3r8RuvgbX9s7ammBn07D3W                89                 86
# 43  6Sq7ltF9Qa7SNFBsV5Cogx                89                100
# 44  5IgjP7X4th6nMNDh4akUHb                89                 91
# 45  1bDbXMyjaUIooNwFE9wn0N                89                 98
# 46  0VjIjW4GlUZAMYd2vXMi3b                88                 99
# 47  1DxEbt6OSbrkRthk6pjZue                87                 75
# 48  0CYTGMBYkwUxrj1MWDLrC5                88                 94
# 49  4uqJelb9THHmJ3OCohg4ZJ                75                 74
#
#                                          artist genre  acousticness  \
# 0    [reggaeton, reggaeton colombiano, urbano latino]       0.67300
# 1      [canadian contemporary r&b, canadian pop, pop]       0.23200
# 2                                               [pop]       0.06320
# 3                                          [pop, r&b]       0.05210
# 4                                                  []       0.25200
# 5   [argentine hip hop, pop venezolano, trap argen...       0.27400
# 6                                               [pop]       0.34200
# 7                                               [rap]       0.41700
# 8           [latin hip hop, reggaeton, urbano latino]       0.04920
# 9                                      [nigerian pop]       0.38200
# 10                                      [pop, uk pop]       0.01100
# 11                              [alternative hip hop]       0.45800
# 12  [colombian pop, latin pop, reggaeton, reggaeto...       0.58300
# 13                             [contemporary country]       0.46700
# 14         [big room, dance pop, edm, pop, pop dance]       0.00383
# 15     [canadian contemporary r&b, canadian pop, pop]       0.11100
# 16  [puerto rican pop, reggaeton, trap latino, urb...       0.00302
# 17              [dance pop, pop, uk contemporary r&b]       0.13800
# 18                                      [bedroom pop]       0.53400
# 19                                              [pop]       0.13000
# 20                          [k-pop, k-pop girl group]       0.35700
# 21                     [gen z singer-songwriter, pop]       0.77700
# 22     [canadian contemporary r&b, canadian pop, pop]       0.14100
# 23   [reggaeton, reggaeton colombiano, urbano latino]       0.33400
# 24                                     [k-pop, k-rap]       0.53200
# 25                                   [chill pop, pop]       0.71700
# 26                                 [modern indie pop]       0.65300
# 27          [latin hip hop, reggaeton, urbano latino]       0.11100
# 28  [argentine hip hop, pop venezolano, trap argen...       0.01250
# 29  [corrido, corridos tumbados, musica mexicana, ...       0.15200
# 30  [new jersey underground rap, rap, trap queen, ...       0.03000
# 31                                  [piano rock, pop]       0.09880
# 32  [garage rock, modern rock, permanent wave, roc...       0.13600
# 33                                     [sad sierreno]       0.09650
# 34  [colombian pop, pop reggaeton, reggaeton colom...       0.08630
# 35                              [dance pop, pop, r&b]       0.02670
# 36                                         [pop, r&b]       0.14100
# 37                      [boston folk, indie pop, pop]       0.47300
# 38                                [modern rock, rock]       0.02010
# 39               [melodic rap, philly rap, rap, trap]       0.06520
# 40  [corrido, corridos tumbados, nueva musica mexi...       0.29900
# 41                    [detroit hip hop, hip hop, rap]       0.20900
# 42                          [k-pop, k-pop girl group]       0.02700
# 43            [reggaeton, trap latino, urbano latino]       0.09010
# 44                                   [dance pop, r&b]       0.06350
# 45  [canadian hip hop, canadian pop, hip hop, rap,...       0.05030
# 46     [canadian contemporary r&b, canadian pop, pop]       0.00146
# 47                      [trap argentino, trap triste]       0.43100
# 48  [colombian pop, pop reggaeton, reggaeton colom...       0.11400
# 49                                    [sertanejo pop]       0.33800
#
#     danceability  energy  instrumentalness  loudness  speechiness    tempo  \
# 0          0.720   0.630          0.000000    -3.547       0.2770  179.974
# 1          0.531   0.525          0.000000    -6.500       0.0671   66.900
# 2          0.707   0.681          0.000005    -4.325       0.0668  117.999
# 3          0.644   0.735          0.144000    -5.747       0.0391   88.980
# 4          0.696   0.809          0.000128    -8.254       0.0500  132.962
# 5          0.778   0.632          0.000000    -5.600       0.0493  122.104
# 6          0.520   0.731          0.001010    -5.338       0.0557  173.930
# 7          0.715   0.620          0.000000    -6.005       0.0484   97.950
# 8          0.783   0.729          0.000272    -3.549       0.0691  167.968
# 9          0.801   0.806          0.000669    -5.206       0.0381  106.999
# 10         0.712   0.463          0.000003    -7.399       0.0797  131.199
# 11         0.637   0.768          0.001920    -6.468       0.0560   94.982
# 12         0.835   0.679          0.000002    -5.329       0.0364  124.980
# 13         0.492   0.675          0.000000    -5.456       0.0389  203.759
# 14         0.561   0.965          0.000007    -3.673       0.0343  128.040
# 15         0.586   0.525          0.000000    -7.163       0.0615  133.629
# 16         0.901   0.589          0.000237    -6.713       0.2890   98.002
# 17         0.538   0.742          0.000047    -5.355       0.1140   96.107
# 18         0.574   0.469          0.000092    -8.209       0.0254  132.023
# 19         0.637   0.643          0.000002    -6.571       0.0519   97.008
# 20         0.804   0.771          0.000003    -4.067       0.0433  126.956
# 21         0.551   0.550          0.000000    -5.339       0.0286  101.190
# 22         0.679   0.587          0.000006    -7.015       0.2760  186.003
# 23         0.794   0.807          0.000000    -3.447       0.3260  178.003
# 24         0.681   0.821          0.001110    -5.120       0.1310   94.074
# 25         0.442   0.538          0.000029    -8.550       0.0451  122.758
# 26         0.515   0.593          0.162000    -4.801       0.0322   94.467
# 27         0.887   0.234          0.670000   -14.520       0.1780  140.020
# 28         0.621   0.782          0.033000    -5.548       0.0440  128.033
# 29         0.772   0.730          0.000107    -6.657       0.0972  136.175
# 30         0.954   0.516          0.000008    -5.817       0.1600  105.001
# 31         0.697   0.802          0.000036    -6.412       0.0456  139.951
# 32         0.464   0.417          0.022000    -9.345       0.0256   67.528
# 33         0.784   0.826          0.000071    -6.340       0.0538  138.078
# 34         0.865   0.573          0.000000    -5.501       0.0678   94.999
# 35         0.684   0.607          0.000307    -8.127       0.1000   81.001
# 36         0.559   0.551          0.000000    -7.231       0.1320  143.008
# 37         0.516   0.322          0.001940   -11.762       0.0292  148.005
# 38         0.772   0.750          0.000000    -3.670       0.0455  114.061
# 39         0.486   0.545          0.004740    -7.924       0.0336  150.187
# 40         0.529   0.602          0.000000    -4.629       0.0458  157.643
# 41         0.637   0.678          0.000000    -3.798       0.2660   84.039
# 42         0.814   0.641          0.000000    -5.957       0.1110  133.854
# 43         0.911   0.712          0.000027    -5.105       0.0817   92.005
# 44         0.733   0.690          0.000001    -5.529       0.0427  116.992
# 45         0.561   0.520          0.000002    -9.342       0.2440  153.150
# 46         0.514   0.730          0.000095    -5.934       0.0598  171.005
# 47         0.838   0.790          0.000003    -1.602       0.1080   92.927
# 48         0.743   0.831          0.000064    -4.042       0.0584   95.975
# 49         0.691   0.708          0.000000    -4.821       0.1950  160.018
#
#     valence
# 0    0.6070
# 1    0.5020
# 2    0.6460
# 3    0.4180
# 4    0.8570
# 5    0.4980
# 6    0.6620
# 7    0.1720
# 8    0.5800
# 9    0.8020
# 10   0.2060
# 11   0.2970
# 12   0.8500
# 13   0.4780
# 14   0.3040
# 15   0.5080
# 16   0.3990
# 17   0.2500
# 18   0.2880
# 19   0.5330
# 20   0.7390
# 21   0.3420
# 22   0.4860
# 23   0.5750
# 24   0.8130
# 25   0.1390
# 26   0.1530
# 27   0.1970
# 28   0.5500
# 29   0.7860
# 30   0.6240
# 31   0.8220
# 32   0.4790
# 33   0.8930
# 34   0.5630
# 35   0.4980
# 36   0.3920
# 37   0.2610
# 38   0.5870
# 39   0.0385
# 40   0.7560
# 41   0.2540
# 42   0.1830
# 43   0.4250
# 44   0.3100
# 45   0.4240
# 46   0.3340
# 47   0.9620
# 48   0.6090
# 49   0.6020
